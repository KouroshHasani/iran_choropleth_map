# %%
from pathlib import Path
from src.data import DATA_DIR

# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt

# %%
nyc_map = gpd.read_file(DATA_DIR / "polbnda_irn.shp")
stats = pd.read_csv(DATA_DIR / "polbnda_irn.csv")

# %%
map_and_stats = nyc_map.merge(stats, on="nam")

# %%
fig, ax = plt.subplots(1, figsize=(8, 8))
plt.xticks(rotation=90)
map_and_stats.plot(column="stat", cmap="Reds", linewidth=0.4, ax=ax, edgecolor=".4")
# Out:
# <AxesSubplot:>
